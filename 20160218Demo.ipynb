# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.technologyreview.com/'
res = requests.get(url)
soup = BeautifulSoup(res.text)
h2 = soup.select('.hp-daily__tz__title')
for h in h2:
    print h.text

# %%
url = 'https://www.thsrc.com.tw/tw/TimeTable/SearchResult'
playload = {
    'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
    'EndStation':'f2519629-5973-4d08-913b-479cce78a356',
    'SearchDate':'2016/02/18',
    'SearchTime':'10:30',
    'SearchWay':'DepartureInMandarin',
    'RestTime':'',
    'EarlyOrLater':''
}
res = requests.post(url,data=playload)

# %%
soup = BeautifulSoup(res.text)
trs = soup.select('tr')
for tr in trs[1:]:
    print tr.text.strip()
# Out:
# 0627
# 10:36
# 12:36
#
#
#
#
#
# close
# 0627 列車 停靠說明
#
# 台北站10:36
# 板橋站10:45
# 桃園站11:00
# 新竹站11:13
# 苗栗站
# 台中站11:39
# 彰化站
# 雲林站
# 嘉義站12:04
# 台南站12:23
# 左營站12:36
# 0627
# 10:36
# 12:36
# 1261
# 10:54
# 12:42
#
#
#
#
#
# close
# 1261 列車 停靠說明
#
# 台北站10:54
# 板橋站11:03
# 桃園站
# 新竹站
# 苗栗站
# 台中站11:46
# 彰化站
# 雲林站
# 嘉義站12:10
# 台南站12:29
# 左營站12:42
# 1261
# 10:54
# 12:42
# 0831
# 11:00
# 13:18
#
#
#
#
#
# close
# 0831 列車 停靠說明
#
# 台北站11:00
# 板橋站11:08
# 桃園站11:21
# 新竹站11:33
# 苗栗站11:45
# 台中站12:06
# 彰化站12:19
# 雲林站12:30
# 嘉義站12:45
# 台南站13:04
# 左營站13:18
# 0831
# 11:00
# 13:18
# 0133
# 11:24
# 13:00
#
#
#
#
#
# close
# 0133 列車 停靠說明
#
# 台北站11:24
# 板橋站11:33
# 桃園站
# 新竹站
# 苗栗站
# 台中站12:15
# 彰化站
# 雲林站
# 嘉義站
# 台南站
# 左營站13:00
# 0133
# 11:24
# 13:00
# 0633
# 11:36
# 13:36
#
#
#
#
#
# close
# 0633 列車 停靠說明
#
# 台北站11:36
# 板橋站11:45
# 桃園站12:00
# 新竹站12:13
# 苗栗站
# 台中站12:39
# 彰化站
# 雲林站
# 嘉義站13:04
# 台南站13:23
# 左營站13:36
# 0633
# 11:36
# 13:36
# 0837
# 12:00
# 14:18
#
#
#
#
#
# close
# 0837 列車 停靠說明
#
# 台北站12:00
# 板橋站12:08
# ...

# %%
url = 'https://www.thsrc.com.tw/index.html?force=1'
res = requests.get(url)
res.encoding = 'utf-8'

# %%
import shutil
url = 'http://ichef.bbci.co.uk/wwfeatures/976_549/images/live/p0/3j/vk/p03jvkt7.jpg'

r = requests.get(settings.STATICMAP_URL.format(**data), stream=True)
if r.status_code == 200:
    with open(path, 'wb') as f:
        r.raw.decode_content = True
        shutil.copyfileobj(r.raw, f)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-94-b5187ea577d9> in <module>()
#       1 from PIL import Image
#       2 url = 'http://ichef.bbci.co.uk/wwfeatures/976_549/images/live/p0/3j/vk/p03jvkt7.jpg'
# ----> 3 im = Image.open(url)
#
# /usr/local/lib/python2.7/site-packages/PIL/Image.pyc in open(fp, mode)
#    2235     if isPath(fp):
#    2236         filename = fp
# -> 2237         fp = builtins.open(fp, "rb")
#    2238     else:
#    2239         filename = ""
#
# IOError: [Errno 2] No such file or directory: 'http://ichef.bbci.co.uk/wwfeatures/976_549/images/live/p0/3j/vk/p03jvkt7.jpg'
